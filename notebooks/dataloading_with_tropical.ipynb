# %%
from ibtracs import Ibtracs
I = Ibtracs()

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 2
#       1 storm = basin.get_storm(("Matthew",2016))
# ----> 2 storm.plot()
#
# File ~/.virtualenvs/cyclone_tracking_ML4GD/lib/python3.11/site-packages/tropycal/tracks/storm.py:720, in Storm.plot(self, domain, plot_all_dots, ax, cartopy_proj, save_path, **kwargs)
#     716     self.plot_obj.create_cartopy(
#     717         proj='PlateCarree', central_longitude=0.0)
#     719 # Plot storm
# --> 720 plot_ax = self.plot_obj.plot_storms(
#     721     [self.dict], domain, plot_all_dots=plot_all_dots, ax=ax, prop=prop, map_prop=map_prop, save_path=save_path)
#     723 # Return axis
#     724 return plot_ax
#
# ...
